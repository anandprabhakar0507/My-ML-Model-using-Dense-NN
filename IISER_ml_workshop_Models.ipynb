# %% [markdown]
# <a href="https://colab.research.google.com/github/anandprabhakar0507/My-ML-Model-using-Dense-NN/blob/master/IISER_ml_workshop_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('housepricedata.csv')
dataset =  df.values

X = dataset[:,0:10]
Y = dataset[:,10]
from sklearn import preprocessing

#scale all input values so they lie between 0 and 1
X_scale = preprocessing.MinMaxScaler().fit_transform(X)

from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3)


from keras.models import Sequential

from keras.layers import Dense

model = Sequential([Dense(32,activation='relu',input_shape = (10,)),Dense(32,activation ='relu'),Dense(1,activation='sigmoid'),])

model.compile(optimizer= 'sgd',loss='binary_crossentropy',metrics =['accuracy'])

hist = model.fit(X_train,Y_train,batch_size=2,epochs=100)

acc = model.evaluate(X_test,Y_test)[1]

print("Test Accuracy = " +str(acc))
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 1022/1022 [==============================] - 1s 769us/step - loss: 0.6778 - accuracy: 0.6204
# Epoch 2/100
# 1022/1022 [==============================] - 1s 500us/step - loss: 0.6288 - accuracy: 0.7524
# Epoch 3/100
# 1022/1022 [==============================] - 1s 508us/step - loss: 0.5323 - accuracy: 0.7847
# Epoch 4/100
# 1022/1022 [==============================] - 1s 521us/step - loss: 0.4188 - accuracy: 0.8395
# Epoch 5/100
# 1022/1022 [==============================] - 1s 517us/step - loss: 0.3498 - accuracy: 0.8640
# Epoch 6/100
# 1022/1022 [==============================] - 1s 524us/step - loss: 0.3179 - accuracy: 0.8738
# Epoch 7/100
# 1022/1022 [==============================] - 1s 495us/step - loss: 0.3043 - accuracy: 0.8787
# Epoch 8/100
# 1022/1022 [==============================] - 1s 494us/step - loss: 0.2922 - accuracy: 0.8836
# Epoch 9/100
# ...

# %%
dir(Sequential)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_inbound_node',
#  '_add_unique_metric_name',
#  '_base_init',
#  '_cache_output_metric_attributes',
#  '_check_trainable_weights_consistency',
#  '_get_callback_model',
#  '_get_existing_metric',
#  '_get_node_attribute_at_index',
#  '_get_training_eval_metrics',
#  '_handle_metrics',
#  '_handle_per_output_metrics',
#  '_init_graph_network',
#  '_init_subclassed_network',
#  '_make_predict_function',
#  '_make_test_function',
#  '_make_train_function',
#  '_node_key',
#  '_prepare_total_loss',
# ...

# %%
dir(keras.utils)
# Out:
# ['CustomObjectScope',
#  'GeneratorEnqueuer',
#  'H5Dict',
#  'HDF5Matrix',
#  'OrderedEnqueuer',
#  'Progbar',
#  'Sequence',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'conv_utils',
#  'convert_all_kernels_in_model',
#  'custom_object_scope',
#  'data_utils',
#  'deserialize_keras_object',
#  'generic_utils',
#  'get_custom_objects',
#  'get_file',
#  'get_source_inputs',
#  'io_utils',
#  'layer_utils',
#  'losses_utils',
#  'metrics_utils',
#  'model_to_dot',
#  'multi_gpu_model',
#  'multi_gpu_utils',
#  'normalize',
#  'np_utils',
#  'plot_model',
#  'print_summary',
#  'serialize_keras_object',
#  'to_categorical',
#  'vis_utils']

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
from keras.utils import np_utils

from keras.datasets import mnist
(X_train,Y_train),(X_test,Y_test) = mnist.load_data()

X_train = X_train.reshape(60000,784)
X_test = X_test.reshape(10000,784)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

Y_train = np_utils.to_categorical(Y_train,512)
Y_test = np_utils.to_categorical(Y_test,512)



model = Sequential([Dense(512,activation = 'relu'),Dense(512,activation ='relu')],)
model.add(Dropout(0.2))
model.compile(optimizer= 'adam',loss='categorical_crossentropy',metrics = ['accuracy'])
model.fit(X_train,Y_train,batch_size=128,epochs=20)
loss,acc = model.evaluate(X_test,Y_test)
acc
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 7s 121us/step - loss: nan - accuracy: 0.1236
# Epoch 2/20
# 60000/60000 [==============================] - 7s 121us/step - loss: nan - accuracy: 0.0987
# Epoch 3/20
# 60000/60000 [==============================] - 7s 121us/step - loss: nan - accuracy: 0.0987
# Epoch 4/20
# 60000/60000 [==============================] - 7s 121us/step - loss: nan - accuracy: 0.0987
# Epoch 5/20
# 60000/60000 [==============================] - 7s 119us/step - loss: nan - accuracy: 0.0987
# Epoch 6/20
# 60000/60000 [==============================] - 7s 117us/step - loss: nan - accuracy: 0.0987
# Epoch 7/20
# 60000/60000 [==============================] - 7s 117us/step - loss: nan - accuracy: 0.0987
# Epoch 8/20
# 60000/60000 [==============================] - 7s 120us/step - loss: nan - accuracy: 0.0987
# Epoch 9/20
# 60000/60000 [==============================] - 7s 118us/step - loss: nan - accuracy: 0.0987
# Epoch 10/20
# ...
